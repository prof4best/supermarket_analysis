# %% [markdown]
# <a href="https://colab.research.google.com/github/prof4best/supermarket_analysis/blob/main/Students_Performance_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
os.chdir(r'/content/drive/MyDrive/')

# %%
df = pd.read_csv('student_academic_performance.csv')

# %%
df
# Out:
#      Student_ID     Student_Name   Age  Gender        Department  Level  \
# 0            87    Grace Adebayo  21.0  Female        Accounting    400
# 1            24     Henry Okafor  18.0  Female   Library Science    200
# 2            63    Michael Peter  20.0    Male        Accounting    300
# 3            95     Henry Mensah  20.0  Female        Accounting    200
# 4            53      Queen Peter  22.0  Female  Computer Science    300
# ..          ...              ...   ...     ...               ...    ...
# 148         121    Faith Adebayo  24.0    Male   Nursing Science    300
# 149         113  Obinna Williams  22.0  Female   Nursing Science    400
# 150          49     Faith Okafor  22.0  Female    Business Admin    200
# 151           5     Samuel Peter  20.0  Female   Nursing Science    400
# 152          57     Brian Essien  20.0    Male   Library Science    400
#
#      Attendance_Percent  Study_Hours_Per_Week  Assignment_Score  \
# ...
